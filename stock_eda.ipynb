# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
tesla = pd.read_csv('Historical_Stock_Data/TSLAStock.csv')
tesla
# Out:
#             Date  Close/Last    Volume        Open        High       Low
# 0     12/09/2020     $604.48  71291190     $653.69     $654.32      $588
# 1     12/08/2020     $649.88  64265030    $625.505     $651.28    $618.5
# 2     12/07/2020     $641.76  56309710   $604.9197   $648.7856   $603.05
# 3     12/04/2020     $599.04  29401310     $591.01     $599.04    $585.5
# 4     12/03/2020     $593.38  42552000     $590.02     $598.97   $582.43
# ...          ...         ...       ...         ...         ...       ...
# 1254  12/16/2015     $46.902  25502215      $44.42     $46.976   $44.146
# 1255  12/15/2015     $44.218  11208430     $44.364     $44.444     $43.6
# 1256  12/14/2015     $43.716  14138985     $43.502     $44.184   $42.974
# 1257  12/11/2015     $43.404  16295570     $45.048      $45.15   $43.328
# 1258  12/10/2015     $45.414  10350440     $44.942     $45.698   $44.728
#
# [1259 rows x 6 columns]

# %%
tesla.columns = ['Date', 'Close', 'Volume', 'Open', 'High', 'Low']

# %%
fig = plt.figure(figsize = (10, 5))
plt.plot(tesla['Date'], tesla['Close'], color ='blue') 
plt.xlabel("Date") 
plt.xticks(rotation=90)
plt.ylabel("Closing Price") 
plt.title("Closing Price per Day") 
plt.show()
