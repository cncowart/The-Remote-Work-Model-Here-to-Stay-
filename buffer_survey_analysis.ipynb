# %%
import pandas as pd

# %%
buffer_2019 = pd.read_csv('buffer_remote/State_of_Remote_2019_Buffer.csv', usecols = [ 'What industry do you work in?',
                                                                                                  'In the following list, what best describes the work you do?',
                                                                                                  'What percentage of the time do you work remotely?',
                                                                                                  'Which of the following statements best describes you:',
                                                                                                  'Would you like to work remotely, at least some of the time, for the rest of your career?',
                                                                                                  'Do you encourage others to work remotely? (This can be anyone in your life from coworkers to friends and family.)',
                                                                                                  "What is your biggest struggle with working remotely?",
                                                                                                  'What is the biggest benefit you see to working remotely?',
                                                                                                  'What location do you primarily work from?',
                                                                                                  "What is your company's stance on remote work?",
                                                                                                  'What percentage of your company works remotely?'])
buffer_2019
# Out:
#      What industry do you work in?  \
# 0                         Software
# 1                  IT and Services
# 2                              NaN
# 3                Consumer products
# 4                        Marketing
# ...                            ...
# 2466                      Software
# 2467                      Software
# 2468                     Marketing
# 2469                           NaN
# 2470                           NaN
#
#      In the following list, what best describes the work you do?  \
# 0                                      Customer Support
# 1                                      Customer Support
# 2                                                   NaN
# 3                                       Human Resources
# 4                             Marketing and Advertising
# ...                                                 ...
# 2466                          Marketing and Advertising
# 2467                                         Leadership
# ...

# %%
type_work19 = buffer_2019['In the following list, what best describes the work you do?'].value_counts(normalize=True) * 100
type_work19
# Out:
# Engineering                  33.484780
# Marketing and Advertising    19.809178
# Leadership                    8.587006
# Design                        7.632894
# Operations                    6.724216
# Customer Support              6.315311
# Product                       5.724671
# Human Resources               3.998183
# Sales                         3.725579
# Data                          2.771468
# Finances                      1.226715
# Name: In the following list, what best describes the work you do?, dtype: float64

# %%
struggle19 = buffer_2019['What is your biggest struggle with working remotely?'].value_counts(normalize=True) * 100
struggle19
# Out:
# Unplugging after work                           22.954445
# Loneliness                                      19.725785
# Collaborating and/or communication              18.266254
# Distractions at home                            10.968598
# Being in a different timezone than teammates     8.801415
# Staying motivated                                8.757187
# Taking vacation time                             6.943830
# Finding reliable wifi                            3.582486
# Name: What is your biggest struggle with working remotely?, dtype: float64

# %%
recomm19 = buffer_2019['Do you encourage others to work remotely? (This can be anyone in your life from coworkers to friends and family.)'].value_counts(normalize=True) * 100
recomm19
# Out:
# 1.0    95.135364
# 0.0     4.864636
# Name: Do you encourage others to work remotely? (This can be anyone in your life from coworkers to friends and family.), dtype: float64

# %%
wk_rem_career19 = buffer_2019['Would you like to work remotely, at least some of the time, for the rest of your career?'].value_counts(normalize=True) * 100
wk_rem_career19
# Out:
# 1.0    98.56176
# 0.0     1.43824
# Name: Would you like to work remotely, at least some of the time, for the rest of your career?, dtype: float64

# %%
pct_rem19 = buffer_2019['What percentage of the time do you work remotely?'].value_counts(normalize=True) * 100
pct_rem19
# Out:
# 100%         55.720339
# 76 to 99%    16.567797
# 1 to 25%     13.008475
# 26 to 50%     8.008475
# 51 to 75%     6.694915
# Name: What percentage of the time do you work remotely?, dtype: float64

# %%
buffer_2020 = pd.read_csv('buffer_remote/StateOfRemoteWork2020byBuffer_AngelList.csv', usecols = ['Do you work remotely sometimes?',
                                                                                                  'What industry do you work in?',
                                                                                                  'In the following list, what best describes the work you do?',
                                                                                                  'What percentage of the time do you work remotely?',
                                                                                                  'Which of the following statements best describes you:',
                                                                                                  'Would you like to work remotely, at least some of the time, for the rest of your career?',
                                                                                                  'Would you recommend remote work to others?',
                                                                                                  "What is your biggest struggle with working remotely?",
                                                                                                  'What is the biggest benefit you see to working remotely?',
                                                                                                  'What location do you primarily work from?',
                                                                                                  "What is your company's stance on remote work?",
                                                                                                  'What percentage of your company works remotely?'])
buffer_2020
# Out:
#       Do you work remotely sometimes? What industry do you work in?  \
# 0                                   1            Travel and Tourism
# 1                                   1                      Software
# 2                                   1                      Software
# 3                                   1               IT and Services
# 4                                   1            Travel and Tourism
# ...                               ...                           ...
# 3516                                1               IT and Services
# 3517                                1            Financial Services
# 3518                                1                      Software
# 3519                                1                           NaN
# 3520                                1                           NaN
#
#      In the following list, what best describes the work you do?  \
# 0                             Marketing and Advertising
# ...

# %%
type_work = buffer_2020['In the following list, what best describes the work you do?'].value_counts(normalize=True) * 100
type_work
# Out:
# Engineering                  36.156839
# Marketing and Advertising    13.379228
# Leadership                    9.368453
# Design                        7.452858
# Product                       7.243340
# Operations                    6.854235
# Customer Support              6.375337
# Sales                         4.340018
# Data                          3.831188
# Human Resources               3.501946
# Finances                      1.496558
# Name: In the following list, what best describes the work you do?, dtype: float64

# %%
struggle = buffer_2020['What is your biggest struggle with working remotely?'].value_counts(normalize=True) * 100
struggle
# Out:
# Difficulties with collaboration and communication    21.051051
# Loneliness                                           20.870871
# Not being able to unplug                             19.099099
# Distractions at home                                 12.642643
# Being in a different timezone than teammates         10.420420
# Staying motivated                                     7.417417
# Taking vacation time                                  4.924925
# Finding reliable wifi                                 3.573574
# Name: What is your biggest struggle with working remotely?, dtype: float64

# %%
industry = buffer_2020['What industry do you work in?'].value_counts(normalize=True) * 100
industry
# Out:
# Software                  43.811275
# IT and Services           21.017157
# Marketing                  9.375000
# Financial Services         4.993873
# Media and Publishing       3.860294
# Education                  3.523284
# E-commerce                 3.247549
# Medical and Healthcare     3.186275
# Consumer products          2.481618
# Travel and Tourism         1.685049
# Non-profit                 1.593137
# Government                 0.612745
# Law and Legal Services     0.612745
# Name: What industry do you work in?, dtype: float64

# %%
pct_rem = buffer_2020['What percentage of the time do you work remotely?'].value_counts(normalize=True) * 100
pct_rem
# Out:
# 100%         56.699858
# 76 to 99%    16.529161
# 1 to 25%     10.014225
# 51 to 75%     8.648649
# 26 to 50%     8.108108
# Name: What percentage of the time do you work remotely?, dtype: float64

# %%
wk_rem_careeer = buffer_2020['Would you like to work remotely, at least some of the time, for the rest of your career?'].value_counts(normalize=True) * 100
wk_rem_careeer
# Out:
# 1    98.06873
# 0     1.93127
# Name: Would you like to work remotely, at least some of the time, for the rest of your career?, dtype: float64

# %%
rem_benefit =  buffer_2020['What is the biggest benefit you see to working remotely?'].value_counts(normalize=True) * 100
rem_benefit
# Out:
# Ability to have a flexible schedule      32.865086
# Flexibility to work from any location    26.807141
# Not having to commute                    21.978344
# Ability to spend time with family        10.945274
# Ability to work from home                 7.404156
# Name: What is the biggest benefit you see to working remotely?, dtype: float64

# %%
location =  buffer_2020['What location do you primarily work from?'].value_counts(normalize=True) * 100
location
# Out:
# Home                79.856115
# Company's office     9.064748
# Coworking spaces     7.280576
# Coffee shops         3.309353
# Libraries            0.489209
# Name: What location do you primarily work from?, dtype: float64

# %%
recomm20 =  buffer_2020['Would you recommend remote work to others?'].value_counts(normalize=True) * 100
recomm20
# Out:
# 1    97.273502
# 0     2.726498
# Name: Would you recommend remote work to others?, dtype: float64

# %%
buffer_2020.to_csv(r'buffer_remote\buffer_2020_clean.csv')
