# %%
import requests
import pandas as pd
import pickle
import time
import numpy as np

# %%
with open('api_keys1.pkl', 'rb') as keys_file:
    test = pickle.load(keys_file)
    api_key = test['polygon']

# %%
endpoint = 'https://api.polygon.io/v1/open-close/'

# %%
params = {'ticker' : 'MSFT',
          'date' : '2020-10-14',
         'apikey' : api_key}

# %%
resp = requests.get(endpoint, params = params)

# %%
resp
# Out:
# <Response [404]>

# %%
resp = requests.get('https://api.polygon.io/v1/open-close/AAPL/2020-10-14?apiKey=' + api_key)

# %%
resp
# Out:
# <Response [200]>

# %%
result = resp.json()

# %%
result
# Out:
# {'status': 'OK',
#  'from': '2020-10-14',
#  'symbol': 'AAPL',
#  'open': 121,
#  'high': 123.03,
#  'low': 119.62,
#  'close': 121.19,
#  'volume': 151057198,
#  'afterHours': 121,
#  'preMarket': 121.55}

# %%
AAPL = result

# %%
AAPL = pd.DataFrame(AAPL, index=[0])
AAPL
# Out:
#   status        from symbol  open    high     low   close     volume  \
# 0     OK  2020-10-14   AAPL   121  123.03  119.62  121.19  151057198
#
#    afterHours  preMarket
# 0         121     121.55

# %%
resp = requests.get('https://api.polygon.io/v2/reference/financials/TWTR?limit=5&sort=reportPeriod&apiKey=' + api_key)
resp
# Out:
# <Response [200]>

# %%
result = resp.json()
result
# Out:
# {'status': 'OK',
#  'results': [{'ticker': 'TWTR',
#    'period': 'TA',
#    'calendarDate': '2010-12-31',
#    'reportPeriod': '2010-12-31',
#    'updated': '2020-02-19',
#    'dateKey': '2010-12-31',
#    'capitalExpenditure': -5692000,
#    'costOfRevenue': 43168000,
#    'consolidatedIncome': -67324000,
#    'depreciationAmortizationAndAccretion': 10364000,
#    'dividendsPerBasicCommonShare': 0,
#    'earningBeforeInterestTaxes': -67596000,
#    'earningsBeforeInterestTaxesDepreciationAmortization': -57232000,
#    'EBITDAMargin': -2.024,
#    'earningsBeforeInterestTaxesDepreciationAmortizationUSD': -57232000,
#    'earningBeforeInterestTaxesUSD': -67596000,
#    'earningsBeforeTax': -67541000,
#    'earningsPerBasicShare': -0.89,
#    'earningsPerDilutedShare': -0.89,
#    'earningsPerBasicShareUSD': -0.89,
#    'freeCashFlow': -54429000,
#    'freeCashFlowPerShare': -0.716,
#    'foreignCurrencyUSDExchangeRate': 1,
#    'grossProfit': -14890000,
#    'grossMargin': -0.527,
# ...

# %%
TWTR = result
TWTR = TWTR['results'][4]

# %%
TWTR = pd.DataFrame(TWTR, index = [0])
TWTR
# Out:
#   ticker period calendarDate reportPeriod     updated     dateKey  \
# 0   TWTR     YA   2011-12-31   2011-12-31  2020-02-19  2011-12-31
#
#    accumulatedOtherComprehensiveIncome     assets  assetsCurrent  \
# 0                               -32000  720675000      596068000
#
#    assetsNonCurrent  ...  shareFactor  weightedAverageShares  \
# 0         124607000  ...            1              102544000
#
#    weightedAverageSharesDiluted  salesPerShare  tangibleAssetValue  taxAssets  \
# 0                     102544000          1.037           677496000          0
#
#    incomeTaxExpense  taxLiabilities  tangibleAssetsBookValuePerShare  \
# 0          -1444000        13617000                            6.607
#
#    workingCapital
# 0       548324000
#
# [1 rows x 92 columns]

# %%
resp = requests.get('https://api.polygon.io/v2/reference/financials/FB?limit=5&sort=reportPeriod&apiKey=' + api_key)
resp
result = resp.json()
result
FB = result
FB = FB['results'][4]
FB = pd.DataFrame(FB, index = [0])
FB
# Out:
#   ticker period calendarDate reportPeriod     updated     dateKey  \
# 0     FB     YA   2010-12-31   2010-12-31  2020-04-30  2010-12-31
#
#    accumulatedOtherComprehensiveIncome      assets  assetsCurrent  \
# 0                             -6000000  2990000000     2246000000
#
#    assetsNonCurrent  ...  shareFactor  weightedAverageShares  \
# 0         744000000  ...            1             1107000000
#
#    weightedAverageSharesDiluted  salesPerShare  tangibleAssetValue  taxAssets  \
# 0                    1414000000          1.783          2894000000          0
#
#    incomeTaxExpense  taxLiabilities  tangibleAssetsBookValuePerShare  \
# 0         402000000               0                            2.614
#
#    workingCapital
# 0      1857000000
#
# [1 rows x 92 columns]

# %%
frames = [TWTR, FB]
financials = pd.concat(frames)
financials
# Out:
#   ticker period calendarDate reportPeriod     updated     dateKey  \
# 0   TWTR     YA   2011-12-31   2011-12-31  2020-02-19  2011-12-31
# 0     FB     YA   2010-12-31   2010-12-31  2020-04-30  2010-12-31
#
#    accumulatedOtherComprehensiveIncome      assets  assetsCurrent  \
# 0                               -32000   720675000      596068000
# 0                             -6000000  2990000000     2246000000
#
#    assetsNonCurrent  ...  shareFactor  weightedAverageShares  \
# 0         124607000  ...            1              102544000
# 0         744000000  ...            1             1107000000
#
#    weightedAverageSharesDiluted  salesPerShare  tangibleAssetValue  taxAssets  \
# 0                     102544000          1.037           677496000          0
# 0                    1414000000          1.783          2894000000          0
#
#    incomeTaxExpense  taxLiabilities  tangibleAssetsBookValuePerShare  \
# ...

# %%
f1 = financials[['ticker','propertyPlantEquipmentNet']]

# %%
f1
# Out:
#   ticker  propertyPlantEquipmentNet
# 0   TWTR                   61983000
# 0     FB                  574000000
